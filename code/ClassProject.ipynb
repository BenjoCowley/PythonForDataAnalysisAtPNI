# %% [markdown]
# <a href="https://colab.research.google.com/github/BenjoCowley/PythonForDataAnalysisAtPNI/blob/master/code/ClassProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

### STEP 0: Upload data
#   Find the class project data on the course website/github:
#    https://github.com/BenjoCowley/PythonForDataAnalysisAtPNI
#    (It will be in a .zip file.)
#   Upload this zip to your colab session.
#    (It should be in your working folder with the name 'images_responses.zip'.)


### get data
if True:
  Z = np.load('images_responses.zip')  # This is some fancy zip-file unpacking

  imgs_normal = Z['imgs_normal']
  imgs_gaudy = Z['imgs_gaudy']
  # each (500, 224, 224, 3) --> (num_images, num_row_pixels, num_col_pixels, rgb_channels)
  
  responses_normal = Z['responses_normal']
  responses_gaudy = Z['responses_gaudy']
  # each (100, 500) --> (num_neurons, num_images)

  # Note: imgs_normal[i] and imgs_gaudy[i] correspond to versions of the same ith image
  #  responses_normal[i] are the neural responses to the image imgs_normal[i]


## Step 1:  Visualize responses
#    Use basic statistics, PCA, tSNE, or any other visualization technique!


## Step 2: What images evoke the largest responses for each neuron?
#   Find largest responses (separately for normal and gaudy images)
#   and plot those images.
#   (Hints: use np.imshow(), np.max(), and likely plt.subplot(num_rows, num_cols, iplot))

# to plot an image:
if True:
  plt.figure()
  img = imgs_normal[0]  # just an example image, you can change this
  plt.imshow(img.astype('uint8'), vmin=0, vmax=255)
    #  pixel values are integers between 0 and 255. so we convert images to
    #  uint8 (unsigned integers with 8 bits...so 0 to 255)
    #  and then we make sure imshow's colormap goes from 0 to 255
    #  (else, it would go from min to max pixel values for each image)
  plt.axis('off')
  plt.title('example image')

## Step 3: Come up with your own scientific questions!
#     What are the differences in responses to either normal or gaudy images?
#     Can one neuron's responses be predicted by all the other neurons' responses?
#     What visual features does each neuron "encode"?
#
#    Note: The point here is to have fun!  Take chances, make mistakes, and get messy.
